# %% [markdown]
# # Test comp_util _convert_to_cpu_array array

# %%
import cupy as cp
import dask
import numpy as np
import src.geocat.comp.comp_util as u
import xarray as xr

max_power = 8
chunksize = 10**5
i = 1
ArraySize = 10**1
t_def_arrays = xr.DataArray(cp.random.uniform(low=30,high=104,size=10**i))
rh_def_arrays = xr.DataArray(cp.random.uniform(low=40,high=90,size=10**i))

# %%
type(t_def_arrays)
# Out:
# xarray.core.dataarray.DataArray

# %%
type(t_def_arrays.data)
# Out:
# cupy._core.core.ndarray

# %% [markdown]
# ## Test numpy input

# %%
inputs = [t_def_arrays.data, rh_def_arrays.data]

# %%
a,b = u._convert_to_cpu_array(inputs)

# %%
a
# Out:
# array([37.12770372, 62.38839695, 51.24238027, 40.32909257, 98.20294617,
#        35.64002255, 82.36683872, 45.52950873, 44.52907149, 80.12515211])

# %%
b
# Out:
# array([41.91719263, 84.68964646, 48.42916316, 53.3287027 , 56.55047652,
#        47.51467168, 83.39521168, 72.65600412, 58.58378927, 46.97850053])

# %%
type(b)
# Out:
# numpy.ndarray

# %%
c = u._convert_to_cpu_array(inputs)

# %%
c
# Out:
# [array([37.12770372, 62.38839695, 51.24238027, 40.32909257, 98.20294617,
#         35.64002255, 82.36683872, 45.52950873, 44.52907149, 80.12515211]),
#  array([41.91719263, 84.68964646, 48.42916316, 53.3287027 , 56.55047652,
#         47.51467168, 83.39521168, 72.65600412, 58.58378927, 46.97850053])]

# %% [markdown]
# ## Test Xarray NumPy input

# %%
inputs = [t_def_arrays, rh_def_arrays]
type(inputs[0])
# Out:
# xarray.core.dataarray.DataArray

# %%
a = u._convert_to_cpu_array(inputs)

# %%
type(a[0].data)
# Out:
# numpy.ndarray

# %% [markdown]
# ## Test Xarray Dask input

# %%
t_def_arrays = t_def_arrays.chunk(2)
rh_def_arrays = rh_def_arrays.chunk(2)
inputs = [t_def_arrays, rh_def_arrays]
type(inputs[0])
# Out:
# xarray.core.dataarray.DataArray

# %%
inputs[0]
# Out:
# <xarray.DataArray (dim_0: 10)>
# dask.array<xarray-<this-array>, shape=(10,), dtype=float64, chunksize=(2,), chunktype=cupy.ndarray>
# Dimensions without coordinates: dim_0

# %%
a = u._convert_to_cpu_array(inputs)

# %%
a[0]
# Out:
# <xarray.DataArray 'asnumpy-a6b8ede75fec6121893e11c555aa65fc' (dim_0: 10)>
# dask.array<asnumpy, shape=(10,), dtype=float64, chunksize=(2,), chunktype=numpy.ndarray>
# Dimensions without coordinates: dim_0
