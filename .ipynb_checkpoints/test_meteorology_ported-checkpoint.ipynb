# %%
import unittest

import cupy as cp
import xarray as xr
import dask 
import src.geocat.comp.meteorology as geo

import numpy as np
import time
import pandas as pd
import cupy as cp
from test.test_meteorology import Test_relhum

# %% [markdown]
# ## Testing Numpy input and CPU

# %%
xp = np
p_def = xp.random.uniform(low=2000,high=100800,size=10**3)
t_def = xp.random.uniform(low=194.65,high=302.45,size=10**3)
q_def = xp.random.uniform(low=0,high=0.02038,size=10**3)
rh_gt_2 = geo.relhum(t_def, q_def, p_def, use_gpu = False)

# %% [markdown]
# ## Testing Numpy input and GPU

# %%
xp = np
p_def = xp.random.uniform(low=2000,high=100800,size=10**3)
t_def = xp.random.uniform(low=194.65,high=302.45,size=10**3)
q_def = xp.random.uniform(low=0,high=0.02038,size=10**3)
rh_gt_2 = geo.relhum(t_def, q_def, p_def, use_gpu = True)

# %% [markdown]
# ## Testing Xarray input with CPU

# %%
p = xr.DataArray(p_def).chunk(10)
t = xr.DataArray(t_def).chunk(10)
q = xr.DataArray(q_def).chunk(10)
a = geo.relhum(t, q, p, use_gpu = False)

# %% [markdown]
# ## Testing Xarray input with GPU

# %%
p = xr.DataArray(p_def).chunk(10)
t = xr.DataArray(t_def).chunk(10)
q = xr.DataArray(q_def).chunk(10)
a = geo.relhum(t, q, p, use_gpu = True)

# %% [markdown]
# ## Unittests with CPU!

# %%
test = Test_relhum()

test.setUpClass()
test.test_float_input(use_gpu = False)
test.test_list_input(use_gpu = False)
test.test_numpy_input(use_gpu = False)
test.test_dims_error(use_gpu = False)
test.test_xarray_type_error(use_gpu = False)
test.test_dask_compute(use_gpu = False)
test.test_dask_lazy(use_gpu = False)
# Out:
# 2022-06-24 12:54:12,765 - distributed.diskutils - INFO - Found stale lock file and directory '/glade/u/home/hkashgar/geocat-comp/dask-worker-space/worker-jxc6nbg5', purging
# 2022-06-24 12:54:12,776 - distributed.diskutils - INFO - Found stale lock file and directory '/glade/u/home/hkashgar/geocat-comp/dask-worker-space/worker-cvtowtbl', purging

# %% [markdown]
# ## Unittests with GPU

# %%
test = Test_relhum()

test.setUpClass()
test.test_float_input(use_gpu = True)
test.test_list_input(use_gpu = True)
test.test_numpy_input(use_gpu = True)
test.test_dims_error(use_gpu = True)
test.test_xarray_type_error(use_gpu = True)
test.test_dask_compute(use_gpu = True)
test.test_dask_lazy(use_gpu = True)
# Out:
# /glade/work/hkashgar/conda-envs/geocat/lib/python3.10/site-packages/distributed/node.py:177: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 40538 instead
#   warnings.warn(

# %% [markdown]
# ## Benchmark Results for different Array Sizes

# %%
def test_numpy_input(use_gpu):
    p = np.asarray(p_def)
    t = np.asarray(t_def)
    q = np.asarray(q_def)
    
    assert xp.allclose(geo.relhum(t, q, p,use_gpu), rh_gt_2, atol=0.1)

# %%
#Test_relhum main body
Routine = "Relhum"
print(Routine)
allData = pd.DataFrame()
#For different Array sizes
for i in range(1,8):
    ArraySize = 10**i
    print("Array size: ", ArraySize)
    #for numpy and cupy both
    for xp in [np,cp]:
        #calculation will be repeated 10 time to get the less biased performance results
        repeat = np.zeros([10])
        repsize = 10
        for rep in range(0,repsize):
            #create different sizes of arrays
            p_def = np.random.uniform(low=2000,high=100800,size=10**i)
            t_def = np.random.uniform(low=194.65,high=302.45,size=10**i)
            q_def = np.random.uniform(low=0,high=0.02038,size=10**i)
            if(xp == cp):
                geo.relhum(t_def, q_def, p_def,True)
                cp.cuda.runtime.deviceSynchronize()
                time1 = time.time()
                geo.relhum(t_def, q_def, p_def,True)
                cp.cuda.runtime.deviceSynchronize()
                time2 = time.time()
                repeat[rep] = time2-time1
            else:
                time1 = time.time()
                geo.relhum(t_def, q_def,p_def,False)
                time2 = time.time()
                repeat[rep] = time2-time1
        #save times
        data = {'Routine': np.repeat(Routine, repsize),
                'Approach': np.repeat(xp.__name__ , repsize),
                'ArraySize': np.repeat(ArraySize , repsize),
                'iteration' : np.arange(1,repsize+1),
                'Runtime(s)': repeat}
        new = pd.DataFrame(data)
        allData = pd.concat([allData,new], ignore_index=True)
        print(xp.__name__,np.mean(repeat), "seconds")
# Out:
# Relhum
# Array size:  10
# numpy 0.00011262893676757812 seconds
# cupy 0.00047643184661865233 seconds
# Array size:  100
# numpy 5.702972412109375e-05 seconds
# cupy 0.0005234241485595703 seconds
# Array size:  1000
# numpy 6.81161880493164e-05 seconds
# cupy 0.0005102396011352539 seconds
# Array size:  10000
# numpy 0.00016617774963378906 seconds
# cupy 0.0005033493041992187 seconds
# Array size:  100000
# numpy 0.0016821861267089845 seconds
# cupy 0.0008495330810546875 seconds
# Array size:  1000000
# numpy 0.024734115600585936 seconds
# cupy 0.006180524826049805 seconds
# Array size:  10000000
# numpy 0.45718135833740237 seconds
# cupy 0.05791831016540527 seconds

# %% [markdown]
# ## Plotting

# %%
import matplotlib.pyplot as plt
import numpy as np

arraysizes = np.unique(allData['ArraySize'])
sd_numpy = np.zeros(len(arraysizes))
sd_cupy = np.zeros(len(arraysizes))
y_numpy = np.zeros(len(arraysizes))
y_cupy = np.zeros(len(arraysizes))

for i in range(0,len(arraysizes)):
    cupydata = allData.loc[(allData['ArraySize'] == arraysizes[i]) & (allData['Approach'] == 'cupy')]
    numpydata = allData.loc[(allData['ArraySize'] == arraysizes[i]) & (allData['Approach'] == 'numpy')]
    y_cupy[i] = np.mean(cupydata['Runtime(s)'])
    y_numpy[i] = np.mean(numpydata['Runtime(s)'])
    sd_cupy[i] = np.std(cupydata['Runtime(s)'])
    sd_numpy[i] = np.std(numpydata['Runtime(s)'])

# %%
fig, ax = plt.subplots(figsize=(9, 6))
ax.errorbar(arraysizes, y_numpy, yerr=sd_numpy, fmt='-o')
ax.errorbar(arraysizes, y_cupy, yerr=sd_cupy, fmt='-o')
ax.plot(arraysizes, y_numpy, label='numpy',color="steelblue")
ax.plot(arraysizes, y_cupy, label='cupy',color="darkorange")  # Plot more data on the axes...
ax.legend();  # Add a legend.
ax.set_xlabel('ArraySize')  # Add an x-label to the axes.
ax.set_ylabel('Runtime(s)')  # Add a y-label to the axes.
ax.set_title(("Test_relhum"))
ax.set_xscale('log')
#ax.set_yscale('log')
#plt.savefig("Test_relhum.jpg",dpi=fig.dpi)

# %%
import dask.distributed as dd
client = dd.Client()
# Out:
# /glade/work/hkashgar/conda-envs/geocat/lib/python3.10/site-packages/distributed/node.py:177: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 45837 instead
#   warnings.warn(

# %%
client
# Out:
# <Client: 'tcp://127.0.0.1:45228' processes=2 threads=2, memory=40.00 GiB>

# %% [markdown]
# ## Benchmark Results for different ArraySizes Xarray

# %%
#Test_relhum main body
Routine = "Relhum"
print(Routine)
allData = pd.DataFrame()
#For different Array sizes
for i in range(1,8):
    ArraySize = 10**i
    print("Array size: ", ArraySize)
    #for numpy and cupy both
    for xp in [np,cp]:
        #calculation will be repeated 10 time to get the less biased performance results
        repeat = np.zeros([10])
        repsize = 10
        for rep in range(0,repsize):
            #create different sizes of arrays
            p_def = xr.DataArray(np.random.uniform(low=2000,high=100800,size=10**i))
            t_def = xr.DataArray(np.random.uniform(low=194.65,high=302.45,size=10**i))
            q_def = xr.DataArray(np.random.uniform(low=0,high=0.02038,size=10**i))
            if(xp == cp):
                geo.relhum(t_def, q_def, p_def,True)
                cp.cuda.runtime.deviceSynchronize()
                time1 = time.time()
                geo.relhum(t_def, q_def, p_def,True)
                cp.cuda.runtime.deviceSynchronize()
                time2 = time.time()
                repeat[rep] = time2-time1
            else:
                time1 = time.time()
                geo.relhum(t_def, q_def,p_def,False)
                time2 = time.time()
                repeat[rep] = time2-time1
        #save times
        data = {'Routine': np.repeat(Routine, repsize),
                'Approach': np.repeat(xp.__name__ , repsize),
                'ArraySize': np.repeat(ArraySize , repsize),
                'iteration' : np.arange(1,repsize+1),
                'Runtime(s)': repeat}
        new = pd.DataFrame(data)
        allData = pd.concat([allData,new], ignore_index=True)
        print(xp.__name__,np.mean(repeat), "seconds")
# Out:
# Relhum
# Array size:  10
# numpy 0.008729290962219239 seconds
# cupy 0.01188039779663086 seconds
# Array size:  100
# numpy 0.008551478385925293 seconds
# cupy 0.01072988510131836 seconds
# Array size:  1000
# numpy 0.008908295631408691 seconds
# cupy 0.010882997512817382 seconds
# Array size:  10000
# numpy 0.010633373260498047 seconds
# cupy 0.012745523452758789 seconds
# Array size:  100000
# numpy 0.03271510601043701 seconds
# cupy 0.025705456733703613 seconds
# Array size:  1000000
# numpy 0.26126551628112793 seconds
# cupy 0.15931181907653807 seconds
# Array size:  10000000
# numpy 2.7258759260177614 seconds
# cupy 1.588690209388733 seconds

# %%
#Test_relhum main body
Routine = "Relhum"
print(Routine)
allData = pd.DataFrame()
#For different Array sizes
for i in range(1,8):
    ArraySize = 10**i
    print("Array size: ", ArraySize)
    #for numpy and cupy both
    for xp in [np,cp]:
        #calculation will be repeated 10 time to get the less biased performance results
        repeat = np.zeros([10])
        repsize = 10
        for rep in range(0,repsize):
            #create different sizes of arrays
            p_def = xr.DataArray(np.random.uniform(low=2000,high=100800,size=10**i)).chunk(10)
            t_def = xr.DataArray(np.random.uniform(low=194.65,high=302.45,size=10**i)).chunk(10)
            q_def = xr.DataArray(np.random.uniform(low=0,high=0.02038,size=10**i)).chunk(10)
            if(xp == cp):
                geo.relhum(t_def, q_def, p_def,True)
                cp.cuda.runtime.deviceSynchronize()
                time1 = time.time()
                geo.relhum(t_def, q_def, p_def,True)
                cp.cuda.runtime.deviceSynchronize()
                time2 = time.time()
                repeat[rep] = time2-time1
            else:
                time1 = time.time()
                geo.relhum(t_def, q_def,p_def,False)
                time2 = time.time()
                repeat[rep] = time2-time1
        #save times
        data = {'Routine': np.repeat(Routine, repsize),
                'Approach': np.repeat(xp.__name__ , repsize),
                'ArraySize': np.repeat(ArraySize , repsize),
                'iteration' : np.arange(1,repsize+1),
                'Runtime(s)': repeat}
        new = pd.DataFrame(data)
        allData = pd.concat([allData,new], ignore_index=True)
        print(xp.__name__,np.mean(repeat), "seconds")
# Out:
# Relhum
# Array size:  10
# numpy 0.01473095417022705 seconds
# cupy 0.01720902919769287 seconds
# Array size:  100
# numpy 0.013966536521911621 seconds
# cupy 0.01765270233154297 seconds
# Array size:  1000
# numpy 0.01463625431060791 seconds
# cupy 0.017626047134399414 seconds
# Array size:  10000
# numpy 0.019140291213989257 seconds
# cupy 0.022281193733215333 seconds
# Array size:  100000
# numpy 0.06196260452270508 seconds
# cupy 0.07344069480895996 seconds
# Array size:  1000000
# 2022-06-24 12:56:08,467 - distributed.utils_perf - WARNING - full garbage collections took 40% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:08,630 - distributed.utils_perf - WARNING - full garbage collections took 41% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:08,909 - distributed.utils_perf - WARNING - full garbage collections took 41% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:09,177 - distributed.utils_perf - WARNING - full garbage collections took 41% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:09,335 - distributed.utils_perf - WARNING - full garbage collections took 42% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:10,078 - distributed.utils_perf - WARNING - full garbage collections took 40% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:10,349 - distributed.utils_perf - WARNING - full garbage collections took 41% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:10,510 - distributed.utils_perf - WARNING - full garbage collections took 42% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:10,796 - distributed.utils_perf - WARNING - full garbage collections took 43% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:11,532 - distributed.utils_perf - WARNING - full garbage collections took 42% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:11,695 - distributed.utils_perf - WARNING - full garbage collections took 43% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:11,974 - distributed.utils_perf - WARNING - full garbage collections took 44% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:12,242 - distributed.utils_perf - WARNING - full garbage collections took 44% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:12,401 - distributed.utils_perf - WARNING - full garbage collections took 44% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:13,147 - distributed.utils_perf - WARNING - full garbage collections took 42% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:13,418 - distributed.utils_perf - WARNING - full garbage collections took 42% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:13,579 - distributed.utils_perf - WARNING - full garbage collections took 42% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:13,862 - distributed.utils_perf - WARNING - full garbage collections took 44% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:14,619 - distributed.utils_perf - WARNING - full garbage collections took 42% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:14,783 - distributed.utils_perf - WARNING - full garbage collections took 42% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:15,066 - distributed.utils_perf - WARNING - full garbage collections took 42% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:15,335 - distributed.utils_perf - WARNING - full garbage collections took 44% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:15,492 - distributed.utils_perf - WARNING - full garbage collections took 44% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:16,241 - distributed.utils_perf - WARNING - full garbage collections took 42% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:16,513 - distributed.utils_perf - WARNING - full garbage collections took 42% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:16,771 - distributed.utils_perf - WARNING - full garbage collections took 42% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:16,930 - distributed.utils_perf - WARNING - full garbage collections took 44% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:17,643 - distributed.utils_perf - WARNING - full garbage collections took 42% CPU time recently (threshold: 10%)
# numpy 0.4524348974227905 seconds
# 2022-06-24 12:56:17,804 - distributed.utils_perf - WARNING - full garbage collections took 42% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:18,078 - distributed.utils_perf - WARNING - full garbage collections took 42% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:18,266 - distributed.utils_perf - WARNING - full garbage collections took 45% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:18,530 - distributed.utils_perf - WARNING - full garbage collections took 44% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:19,833 - distributed.utils_perf - WARNING - full garbage collections took 40% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:20,096 - distributed.utils_perf - WARNING - full garbage collections took 40% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:20,257 - distributed.utils_perf - WARNING - full garbage collections took 40% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:20,524 - distributed.utils_perf - WARNING - full garbage collections took 42% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:20,683 - distributed.utils_perf - WARNING - full garbage collections took 42% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:21,990 - distributed.utils_perf - WARNING - full garbage collections took 38% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:22,251 - distributed.utils_perf - WARNING - full garbage collections took 38% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:22,410 - distributed.utils_perf - WARNING - full garbage collections took 40% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:22,691 - distributed.utils_perf - WARNING - full garbage collections took 40% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:23,984 - distributed.utils_perf - WARNING - full garbage collections took 37% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:24,144 - distributed.utils_perf - WARNING - full garbage collections took 37% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:24,422 - distributed.utils_perf - WARNING - full garbage collections took 37% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:24,685 - distributed.utils_perf - WARNING - full garbage collections took 38% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:24,846 - distributed.utils_perf - WARNING - full garbage collections took 38% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:26,156 - distributed.utils_perf - WARNING - full garbage collections took 35% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:26,419 - distributed.utils_perf - WARNING - full garbage collections took 35% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:26,578 - distributed.utils_perf - WARNING - full garbage collections took 37% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:26,858 - distributed.utils_perf - WARNING - full garbage collections took 36% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:28,186 - distributed.utils_perf - WARNING - full garbage collections took 33% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:28,344 - distributed.utils_perf - WARNING - full garbage collections took 34% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:28,624 - distributed.utils_perf - WARNING - full garbage collections took 33% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:28,883 - distributed.utils_perf - WARNING - full garbage collections took 35% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:29,042 - distributed.utils_perf - WARNING - full garbage collections took 35% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:30,381 - distributed.utils_perf - WARNING - full garbage collections took 32% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:30,663 - distributed.utils_perf - WARNING - full garbage collections took 32% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:30,922 - distributed.utils_perf - WARNING - full garbage collections took 33% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:31,089 - distributed.utils_perf - WARNING - full garbage collections took 33% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:32,421 - distributed.utils_perf - WARNING - full garbage collections took 31% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:32,587 - distributed.utils_perf - WARNING - full garbage collections took 31% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:32,851 - distributed.utils_perf - WARNING - full garbage collections took 31% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:33,014 - distributed.utils_perf - WARNING - full garbage collections took 33% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:33,291 - distributed.utils_perf - WARNING - full garbage collections took 33% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:34,587 - distributed.utils_perf - WARNING - full garbage collections took 31% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:34,842 - distributed.utils_perf - WARNING - full garbage collections took 31% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:35,009 - distributed.utils_perf - WARNING - full garbage collections took 31% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:35,269 - distributed.utils_perf - WARNING - full garbage collections took 33% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:35,430 - distributed.utils_perf - WARNING - full garbage collections took 33% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:36,734 - distributed.utils_perf - WARNING - full garbage collections took 31% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:36,993 - distributed.utils_perf - WARNING - full garbage collections took 31% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:37,153 - distributed.utils_perf - WARNING - full garbage collections took 33% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:37,433 - distributed.utils_perf - WARNING - full garbage collections took 33% CPU time recently (threshold: 10%)
# cupy 0.5322043657302856 seconds
# Array size:  10000000
# 2022-06-24 12:56:39,038 - distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:39,212 - distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:39,403 - distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:39,613 - distributed.utils_perf - WARNING - full garbage collections took 33% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:39,847 - distributed.utils_perf - WARNING - full garbage collections took 33% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:40,164 - distributed.utils_perf - WARNING - full garbage collections took 34% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:40,443 - distributed.utils_perf - WARNING - full garbage collections took 34% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:40,754 - distributed.utils_perf - WARNING - full garbage collections took 38% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:42,107 - distributed.utils_perf - WARNING - full garbage collections took 35% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:42,327 - distributed.utils_perf - WARNING - full garbage collections took 36% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:42,583 - distributed.utils_perf - WARNING - full garbage collections took 36% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:42,898 - distributed.utils_perf - WARNING - full garbage collections took 36% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:43,191 - distributed.utils_perf - WARNING - full garbage collections took 40% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:44,498 - distributed.utils_perf - WARNING - full garbage collections took 37% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:44,658 - distributed.utils_perf - WARNING - full garbage collections took 38% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:44,836 - distributed.utils_perf - WARNING - full garbage collections took 38% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:45,041 - distributed.utils_perf - WARNING - full garbage collections took 41% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:45,263 - distributed.utils_perf - WARNING - full garbage collections took 42% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:45,532 - distributed.utils_perf - WARNING - full garbage collections took 42% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:45,847 - distributed.utils_perf - WARNING - full garbage collections took 42% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:46,150 - distributed.utils_perf - WARNING - full garbage collections took 43% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:52,103 - distributed.utils_perf - WARNING - full garbage collections took 32% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:52,302 - distributed.utils_perf - WARNING - full garbage collections took 32% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:52,520 - distributed.utils_perf - WARNING - full garbage collections took 33% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:52,772 - distributed.utils_perf - WARNING - full garbage collections took 33% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:53,087 - distributed.utils_perf - WARNING - full garbage collections took 33% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:53,375 - distributed.utils_perf - WARNING - full garbage collections took 36% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:53,708 - distributed.utils_perf - WARNING - full garbage collections took 36% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:55,161 - distributed.utils_perf - WARNING - full garbage collections took 34% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:55,407 - distributed.utils_perf - WARNING - full garbage collections took 35% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:55,729 - distributed.utils_perf - WARNING - full garbage collections took 38% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:56,012 - distributed.utils_perf - WARNING - full garbage collections took 38% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:56,335 - distributed.utils_perf - WARNING - full garbage collections took 39% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:57,807 - distributed.utils_perf - WARNING - full garbage collections took 36% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:58,040 - distributed.utils_perf - WARNING - full garbage collections took 36% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:58,312 - distributed.utils_perf - WARNING - full garbage collections took 36% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:58,625 - distributed.utils_perf - WARNING - full garbage collections took 36% CPU time recently (threshold: 10%)
# 2022-06-24 12:56:58,948 - distributed.utils_perf - WARNING - full garbage collections took 36% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:05,172 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:05,390 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:05,637 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:05,952 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:06,237 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:06,563 - distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:08,041 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:08,266 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:08,535 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:08,856 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:09,161 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:10,592 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:10,778 - distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:10,987 - distributed.utils_perf - WARNING - full garbage collections took 36% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:11,219 - distributed.utils_perf - WARNING - full garbage collections took 36% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:11,492 - distributed.utils_perf - WARNING - full garbage collections took 36% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:11,806 - distributed.utils_perf - WARNING - full garbage collections took 36% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:12,131 - distributed.utils_perf - WARNING - full garbage collections took 36% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:18,296 - distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:18,515 - distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:18,759 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:19,077 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:19,361 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:19,681 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:21,140 - distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:21,362 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:21,624 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:21,939 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:22,240 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:23,623 - distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:23,794 - distributed.utils_perf - WARNING - full garbage collections took 35% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:23,987 - distributed.utils_perf - WARNING - full garbage collections took 35% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:24,194 - distributed.utils_perf - WARNING - full garbage collections took 35% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:24,430 - distributed.utils_perf - WARNING - full garbage collections took 35% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:24,702 - distributed.utils_perf - WARNING - full garbage collections took 35% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:25,022 - distributed.utils_perf - WARNING - full garbage collections took 35% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:25,341 - distributed.utils_perf - WARNING - full garbage collections took 37% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:31,554 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:31,776 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:32,021 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:32,346 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:32,636 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:32,958 - distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:34,446 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:34,678 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:34,947 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:35,271 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:35,579 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:37,026 - distributed.utils_perf - WARNING - full garbage collections took 36% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:37,220 - distributed.utils_perf - WARNING - full garbage collections took 35% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:37,430 - distributed.utils_perf - WARNING - full garbage collections took 35% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:37,668 - distributed.utils_perf - WARNING - full garbage collections took 35% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:37,942 - distributed.utils_perf - WARNING - full garbage collections took 35% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:38,257 - distributed.utils_perf - WARNING - full garbage collections took 35% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:38,578 - distributed.utils_perf - WARNING - full garbage collections took 38% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:44,785 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:45,006 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:45,247 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:45,518 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:45,835 - distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:46,153 - distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:47,634 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:47,838 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:48,075 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:48,350 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:48,661 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:48,971 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:50,423 - distributed.utils_perf - WARNING - full garbage collections took 35% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:50,620 - distributed.utils_perf - WARNING - full garbage collections took 35% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:50,831 - distributed.utils_perf - WARNING - full garbage collections took 35% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:51,070 - distributed.utils_perf - WARNING - full garbage collections took 35% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:51,395 - distributed.utils_perf - WARNING - full garbage collections took 35% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:51,690 - distributed.utils_perf - WARNING - full garbage collections took 35% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:52,017 - distributed.utils_perf - WARNING - full garbage collections took 38% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:58,338 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:58,562 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:58,817 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:59,141 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:59,442 - distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# 2022-06-24 12:57:59,784 - distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:01,383 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:01,666 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:01,983 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:02,290 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:02,639 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:04,229 - distributed.utils_perf - WARNING - full garbage collections took 36% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:04,489 - distributed.utils_perf - WARNING - full garbage collections took 36% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:04,821 - distributed.utils_perf - WARNING - full garbage collections took 36% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:05,133 - distributed.utils_perf - WARNING - full garbage collections took 36% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:11,667 - distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:11,846 - distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:12,042 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:12,269 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:12,524 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:12,859 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:13,155 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:13,490 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:15,048 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:15,283 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:15,542 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:15,879 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:16,185 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:16,534 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:18,125 - distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:18,382 - distributed.utils_perf - WARNING - full garbage collections took 35% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:18,719 - distributed.utils_perf - WARNING - full garbage collections took 35% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:19,030 - distributed.utils_perf - WARNING - full garbage collections took 36% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:19,387 - distributed.utils_perf - WARNING - full garbage collections took 36% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:26,083 - distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:26,349 - distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:26,684 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:26,997 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:27,347 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:28,881 - distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:29,138 - distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:29,461 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:29,777 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:30,119 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:31,690 - distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:31,951 - distributed.utils_perf - WARNING - full garbage collections took 36% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:32,278 - distributed.utils_perf - WARNING - full garbage collections took 36% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:32,600 - distributed.utils_perf - WARNING - full garbage collections took 36% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:38,920 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:39,093 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:39,290 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:39,520 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:39,776 - distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:40,099 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:40,396 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:40,729 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:42,171 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:42,411 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:42,689 - distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:43,021 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:43,341 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:44,790 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:44,995 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:45,206 - distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:45,452 - distributed.utils_perf - WARNING - full garbage collections took 36% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:45,734 - distributed.utils_perf - WARNING - full garbage collections took 36% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:46,067 - distributed.utils_perf - WARNING - full garbage collections took 36% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:46,399 - distributed.utils_perf - WARNING - full garbage collections took 36% CPU time recently (threshold: 10%)
# numpy 4.782401728630066 seconds
# 2022-06-24 12:58:52,534 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:52,756 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:53,012 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:53,348 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:53,648 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:53,986 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:55,495 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:55,736 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:56,003 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:56,325 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:56,643 - distributed.utils_perf - WARNING - full garbage collections took 39% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:58,076 - distributed.utils_perf - WARNING - full garbage collections took 37% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:58,272 - distributed.utils_perf - WARNING - full garbage collections took 37% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:58,496 - distributed.utils_perf - WARNING - full garbage collections took 37% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:58,739 - distributed.utils_perf - WARNING - full garbage collections took 37% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:59,021 - distributed.utils_perf - WARNING - full garbage collections took 37% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:59,336 - distributed.utils_perf - WARNING - full garbage collections took 37% CPU time recently (threshold: 10%)
# 2022-06-24 12:58:59,664 - distributed.utils_perf - WARNING - full garbage collections took 37% CPU time recently (threshold: 10%)
# 2022-06-24 12:59:11,746 - distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# 2022-06-24 12:59:11,977 - distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# 2022-06-24 12:59:12,231 - distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# 2022-06-24 12:59:12,515 - distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# 2022-06-24 12:59:12,852 - distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# 2022-06-24 12:59:13,184 - distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# 2022-06-24 12:59:14,653 - distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# 2022-06-24 12:59:14,866 - distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# 2022-06-24 12:59:15,105 - distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# 2022-06-24 12:59:15,380 - distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# 2022-06-24 12:59:15,714 - distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# 2022-06-24 12:59:16,035 - distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# 2022-06-24 12:59:17,491 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 12:59:17,687 - distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# 2022-06-24 12:59:17,910 - distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# 2022-06-24 12:59:18,156 - distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# 2022-06-24 12:59:18,432 - distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# 2022-06-24 12:59:18,740 - distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# 2022-06-24 12:59:19,066 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2022-06-24 12:59:31,208 - distributed.utils_perf - WARNING - full garbage collections took 19% CPU time recently (threshold: 10%)
# 2022-06-24 12:59:31,445 - distributed.utils_perf - WARNING - full garbage collections took 19% CPU time recently (threshold: 10%)
# 2022-06-24 12:59:31,707 - distributed.utils_perf - WARNING - full garbage collections took 19% CPU time recently (threshold: 10%)
# 2022-06-24 12:59:32,052 - distributed.utils_perf - WARNING - full garbage collections took 19% CPU time recently (threshold: 10%)
# 2022-06-24 12:59:32,354 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2022-06-24 12:59:32,700 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2022-06-24 12:59:34,241 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2022-06-24 12:59:34,491 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2022-06-24 12:59:34,761 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2022-06-24 12:59:35,106 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2022-06-24 12:59:35,439 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2022-06-24 12:59:36,962 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 12:59:37,164 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 12:59:37,389 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 12:59:37,640 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 12:59:37,915 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 12:59:38,254 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 12:59:38,587 - distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# 2022-06-24 12:59:50,685 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2022-06-24 12:59:50,917 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2022-06-24 12:59:51,170 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2022-06-24 12:59:51,458 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2022-06-24 12:59:51,795 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2022-06-24 12:59:52,129 - distributed.utils_perf - WARNING - full garbage collections took 21% CPU time recently (threshold: 10%)
# 2022-06-24 12:59:53,602 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2022-06-24 12:59:53,828 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2022-06-24 12:59:54,088 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2022-06-24 12:59:54,358 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2022-06-24 12:59:54,697 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2022-06-24 12:59:55,030 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2022-06-24 12:59:56,526 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 12:59:56,741 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 12:59:56,983 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 12:59:57,253 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 12:59:57,588 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 12:59:57,898 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 13:00:09,910 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2022-06-24 13:00:10,096 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2022-06-24 13:00:10,298 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2022-06-24 13:00:10,533 - distributed.utils_perf - WARNING - full garbage collections took 19% CPU time recently (threshold: 10%)
# 2022-06-24 13:00:10,790 - distributed.utils_perf - WARNING - full garbage collections took 19% CPU time recently (threshold: 10%)
# 2022-06-24 13:00:11,081 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2022-06-24 13:00:11,422 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2022-06-24 13:00:11,758 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2022-06-24 13:00:13,206 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2022-06-24 13:00:13,436 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2022-06-24 13:00:13,677 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2022-06-24 13:00:13,960 - distributed.utils_perf - WARNING - full garbage collections took 19% CPU time recently (threshold: 10%)
# 2022-06-24 13:00:14,298 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2022-06-24 13:00:14,633 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2022-06-24 13:00:16,089 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 13:00:16,311 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 13:00:16,551 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 13:00:16,815 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 13:00:17,149 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2022-06-24 13:00:17,463 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2022-06-24 13:00:29,194 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2022-06-24 13:00:29,386 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2022-06-24 13:00:29,596 - distributed.utils_perf - WARNING - full garbage collections took 19% CPU time recently (threshold: 10%)
# 2022-06-24 13:00:29,837 - distributed.utils_perf - WARNING - full garbage collections took 19% CPU time recently (threshold: 10%)
# 2022-06-24 13:00:30,109 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2022-06-24 13:00:30,453 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2022-06-24 13:00:30,765 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2022-06-24 13:00:31,113 - distributed.utils_perf - WARNING - full garbage collections took 21% CPU time recently (threshold: 10%)
# 2022-06-24 13:00:32,626 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2022-06-24 13:00:32,879 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2022-06-24 13:00:33,153 - distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# 2022-06-24 13:00:33,494 - distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# 2022-06-24 13:00:33,836 - distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# 2022-06-24 13:00:35,295 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2022-06-24 13:00:35,516 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2022-06-24 13:00:35,756 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2022-06-24 13:00:36,027 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2022-06-24 13:00:36,347 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 13:00:36,662 - distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# 2022-06-24 13:00:48,536 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2022-06-24 13:00:48,719 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2022-06-24 13:00:48,930 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2022-06-24 13:00:49,173 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2022-06-24 13:00:49,444 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2022-06-24 13:00:50,278 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2022-06-24 13:00:51,533 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2022-06-24 13:00:51,812 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2022-06-24 13:00:52,157 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2022-06-24 13:00:52,494 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2022-06-24 13:00:53,939 - distributed.utils_perf - WARNING - full garbage collections took 19% CPU time recently (threshold: 10%)
# 2022-06-24 13:00:54,139 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 13:00:54,357 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 13:00:54,603 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2022-06-24 13:00:54,877 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2022-06-24 13:00:55,212 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2022-06-24 13:00:55,541 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)

# %%
p_def = xr.DataArray(np.random.uniform(low=2000,high=100800,size=10**3)).chunk(10)

# %%
type(p_def)

# %%
type(p_def.data)

# %%
p_def = xr.DataArray(np.random.uniform(low=2000,high=100800,size=10**3))

# %%
x = p_def.map_blocks(cp.asarray)

# %%
type(x)

# %%
type(p_def.data)

# %%
t = p_def.data.map_blocks(xp.asarray)
mintemp = 173.16
a = (t - mintemp).astype(int)

# %%
xr.DataArray(a).data

# %%
type(t)

# %%
type(p_def)

# %%
t = p_def.data.map_blocks(xp.asarray)
