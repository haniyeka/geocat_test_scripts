# %% [markdown]
# # Strong Scaling

# %%
import time
import unittest
from test.test_meteorology import Test_relhum

#import cupy as cp
import dask
import numpy as np
import pandas as pd
import src.geocat.comp.meteorology as geo
import xarray as xr
csvpath = "relhum_strong_scaling.csv"
import math 
# import dask.array as da
from dask_jobqueue import PBSCluster
from dask.distributed import Client
# Out:
# /glade/work/hkashgar/conda-envs/geocat/lib/python3.10/site-packages/dask_jobqueue/core.py:20: FutureWarning: tmpfile is deprecated and will be removed in a future release. Please use dask.utils.tmpfile instead.
#   from distributed.utils import tmpfile

# %%
Routine = "Relhum"
ArraySize = 10**7
p_def = xr.DataArray(np.random.uniform(low=2000,high=100800,size=ArraySize)).chunk(10**5)
t_def = xr.DataArray(np.random.uniform(low=194.65,high=302.45,size=ArraySize)).chunk(10**5)
q_def = xr.DataArray(np.random.uniform(low=0,high=0.02038,size=ArraySize)).chunk(10**5)

# %% [markdown]
# # CPU

# %% [markdown]
# ## 1 CPU node, 36 cores, 200 GB mem

# %%
cores_per_nodes = 36
mem_per_node = 200
i = 1
ncpus = i*cores_per_nodes
ngpus = i
nodes = i
mem = i*mem_per_node
resourceCPU = 'select={nodes}:ncpus=36:mem=200gb'.format(nodes = nodes)
clusterCPU = PBSCluster(memory='{mem} GB'.format(mem = mem),
                        processes=ncpus,
                        cores=ncpus,
                        queue='casper',
                        walltime='02:00:00',
                        resource_spec=resourceCPU)
print(clusterCPU.job_script())
clusterCPU.scale(1)
client = Client(clusterCPU)
# Out:
# #!/usr/bin/env bash
#
# #PBS -N dask-worker
# #PBS -q casper
# #PBS -A NTDD0005
# #PBS -l select=1:ncpus=36:mem=200gb
# #PBS -l walltime=02:00:00
#
# /glade/work/hkashgar/conda-envs/geocat/bin/python -m distributed.cli.dask_worker tcp://10.12.205.43:37761 --nthreads 1 --nprocs 36 --memory-limit 5.17GiB --name dummy-name --nanny --death-timeout 60 --interface ib0 --protocol tcp://

# %%
client
# Out:
# <Client: 'tcp://10.12.205.43:37761' processes=36 threads=36, memory=186.12 GiB>

# %%
repsize = 10
repeat = np.zeros([repsize])
allData = pd.DataFrame()
for rep in range(repsize):
    numpy_res = geo.relhum(t_def, q_def, p_def,False).compute()
    time1 = time.time()
    numpy_res = geo.relhum(t_def, q_def, p_def,False).compute()
    time2 = time.time()
    repeat[rep] = time2-time1
    #numpy_results.append(numpy_res)
data = {'Routine': np.repeat(Routine, repsize),
        'Input':"Xarray with Dask array input",
        'Approach': np.repeat(np.__name__ , repsize),
        'ArraySize': np.repeat(ArraySize , repsize),
        'nodes': nodes,
        'iteration' : np.arange(1,repsize+1),
        'Runtime(s)': repeat}
allData = pd.concat([allData,pd.DataFrame(data)], ignore_index=True)
try:
    previous = pd.read_csv(csvpath)
    previous = pd.concat([previous,allData])
except FileNotFoundError:
    previous = allData
previous.to_csv(csvpath, index=False)

# %%
allData
# Out:
#   Routine                         Input Approach  ArraySize  nodes  iteration  \
# 0  Relhum  Xarray with Dask array input    numpy   10000000      1          1
# 1  Relhum  Xarray with Dask array input    numpy   10000000      1          2
# 2  Relhum  Xarray with Dask array input    numpy   10000000      1          3
# 3  Relhum  Xarray with Dask array input    numpy   10000000      1          4
# 4  Relhum  Xarray with Dask array input    numpy   10000000      1          5
# 5  Relhum  Xarray with Dask array input    numpy   10000000      1          6
# 6  Relhum  Xarray with Dask array input    numpy   10000000      1          7
# 7  Relhum  Xarray with Dask array input    numpy   10000000      1          8
# 8  Relhum  Xarray with Dask array input    numpy   10000000      1          9
# 9  Relhum  Xarray with Dask array input    numpy   10000000      1         10
#
#    Runtime(s)
# 0    1.036551
# 1    0.902092
# 2    0.912610
# 3    0.905126
# 4    0.890195
# 5    0.893844
# 6    0.857805
# 7    0.918539
# 8    0.924806
# 9    1.005046

# %%
clusterCPU.close()

# %% [markdown]
# ## 2 CPU node, 72 cores, 400 GB mem

# %%
cores_per_nodes = 36
mem_per_node = 200
i = 2
ncpus = i*cores_per_nodes
ngpus = i
nodes = i
mem = i*mem_per_node
resourceCPU = 'select={nodes}:ncpus=36:mem=200gb'.format(nodes = nodes)
clusterCPU = PBSCluster(memory='{mem} GB'.format(mem = mem),
                        processes=ncpus,
                        cores=ncpus,
                        queue='casper',
                        walltime='02:00:00',
                        resource_spec=resourceCPU)
print(clusterCPU.job_script())
clusterCPU.scale(1)
client = Client(clusterCPU)
# Out:
# #!/usr/bin/env bash
#
# #PBS -N dask-worker
# #PBS -q casper
# #PBS -A NTDD0005
# #PBS -l select=2:ncpus=36:mem=200gb
# #PBS -l walltime=02:00:00
#
# /glade/work/hkashgar/conda-envs/geocat/bin/python -m distributed.cli.dask_worker tcp://10.12.205.43:42134 --nthreads 1 --nprocs 72 --memory-limit 5.17GiB --name dummy-name --nanny --death-timeout 60 --interface ib0 --protocol tcp://

# %%
client
# Out:
# <Client: 'tcp://10.12.205.43:42134' processes=72 threads=72, memory=372.24 GiB>

# %%
repsize = 10
repeat = np.zeros([repsize])
allData = pd.DataFrame()
for rep in range(repsize):
    numpy_res = geo.relhum(t_def, q_def, p_def,False).compute()
    time1 = time.time()
    numpy_res = geo.relhum(t_def, q_def, p_def,False).compute()
    time2 = time.time()
    repeat[rep] = time2-time1
    #numpy_results.append(numpy_res)
data = {'Routine': np.repeat(Routine, repsize),
        'Input':"Xarray with Dask array input",
        'Approach': np.repeat(np.__name__ , repsize),
        'ArraySize': np.repeat(ArraySize , repsize),
        'nodes': nodes,
        'iteration' : np.arange(1,repsize+1),
        'Runtime(s)': repeat}
allData = pd.concat([allData,pd.DataFrame(data)], ignore_index=True)
try:
    previous = pd.read_csv(csvpath)
    previous = pd.concat([previous,allData])
except FileNotFoundError:
    previous = allData
previous.to_csv(csvpath, index=False)
# Out:
# 2022-07-19 14:17:15,162 - distributed.client - ERROR - Failed to reconnect to scheduler after 30.00 seconds, closing client

# %%
allData
# Out:
#   Routine                         Input Approach  ArraySize  nodes  iteration  \
# 0  Relhum  Xarray with Dask array input    numpy   10000000      2          1
# 1  Relhum  Xarray with Dask array input    numpy   10000000      2          2
# 2  Relhum  Xarray with Dask array input    numpy   10000000      2          3
# 3  Relhum  Xarray with Dask array input    numpy   10000000      2          4
# 4  Relhum  Xarray with Dask array input    numpy   10000000      2          5
# 5  Relhum  Xarray with Dask array input    numpy   10000000      2          6
# 6  Relhum  Xarray with Dask array input    numpy   10000000      2          7
# 7  Relhum  Xarray with Dask array input    numpy   10000000      2          8
# 8  Relhum  Xarray with Dask array input    numpy   10000000      2          9
# 9  Relhum  Xarray with Dask array input    numpy   10000000      2         10
#
#    Runtime(s)
# 0    1.163980
# 1    1.219444
# 2    1.187842
# 3    1.229194
# 4    1.161776
# 5    0.929864
# 6    0.899710
# 7    0.875280
# 8    0.896441
# 9    0.925093

# %%
clusterCPU.close()

# %% [markdown]
# ## 3 CPU node, 108 cores, 600 GB mem

# %%
cores_per_nodes = 36
mem_per_node = 200
i = 3
ncpus = i*cores_per_nodes
ngpus = i
nodes = i
mem = i*mem_per_node
resourceCPU = 'select={nodes}:ncpus=36:mem=200gb'.format(nodes = nodes)
clusterCPU = PBSCluster(memory='{mem} GB'.format(mem = mem),
                        processes=ncpus,
                        cores=ncpus,
                        queue='casper',
                        walltime='02:00:00',
                        resource_spec=resourceCPU)
print(clusterCPU.job_script())
clusterCPU.scale(1)
client = Client(clusterCPU)
# Out:
# #!/usr/bin/env bash
#
# #PBS -N dask-worker
# #PBS -q casper
# #PBS -A NTDD0005
# #PBS -l select=3:ncpus=36:mem=200gb
# #PBS -l walltime=02:00:00
#
# /glade/work/hkashgar/conda-envs/geocat/bin/python -m distributed.cli.dask_worker tcp://10.12.205.43:33700 --nthreads 1 --nprocs 108 --memory-limit 5.17GiB --name dummy-name --nanny --death-timeout 60 --interface ib0 --protocol tcp://

# %%
client
# Out:
# <Client: 'tcp://10.12.205.43:33700' processes=108 threads=108, memory=558.36 GiB>

# %%
repsize = 10
repeat = np.zeros([repsize])
allData = pd.DataFrame()
for rep in range(repsize):
    numpy_res = geo.relhum(t_def, q_def, p_def,False).compute()
    time1 = time.time()
    numpy_res = geo.relhum(t_def, q_def, p_def,False).compute()
    time2 = time.time()
    repeat[rep] = time2-time1
    #numpy_results.append(numpy_res)
data = {'Routine': np.repeat(Routine, repsize),
        'Input':"Xarray with Dask array input",
        'Approach': np.repeat(np.__name__ , repsize),
        'ArraySize': np.repeat(ArraySize , repsize),
        'nodes': nodes,
        'iteration' : np.arange(1,repsize+1),
        'Runtime(s)': repeat}
allData = pd.concat([allData,pd.DataFrame(data)], ignore_index=True)
try:
    previous = pd.read_csv(csvpath)
    previous = pd.concat([previous,allData])
except FileNotFoundError:
    previous = allData
previous.to_csv(csvpath, index=False)
# Out:
# 2022-07-19 14:19:15,979 - distributed.client - ERROR - Failed to reconnect to scheduler after 30.00 seconds, closing client

# %%
allData
# Out:
#   Routine                         Input Approach  ArraySize  nodes  iteration  \
# 0  Relhum  Xarray with Dask array input    numpy   10000000      3          1
# 1  Relhum  Xarray with Dask array input    numpy   10000000      3          2
# 2  Relhum  Xarray with Dask array input    numpy   10000000      3          3
# 3  Relhum  Xarray with Dask array input    numpy   10000000      3          4
# 4  Relhum  Xarray with Dask array input    numpy   10000000      3          5
# 5  Relhum  Xarray with Dask array input    numpy   10000000      3          6
# 6  Relhum  Xarray with Dask array input    numpy   10000000      3          7
# 7  Relhum  Xarray with Dask array input    numpy   10000000      3          8
# 8  Relhum  Xarray with Dask array input    numpy   10000000      3          9
# 9  Relhum  Xarray with Dask array input    numpy   10000000      3         10
#
#    Runtime(s)
# 0    0.979698
# 1    1.061206
# 2    1.401735
# 3    1.395619
# 4    1.342812
# 5    1.298886
# 6    1.295827
# 7    1.014314
# 8    1.005572
# 9    1.514281

# %%
clusterCPU.close()

# %% [markdown]
# ## 4 CPU nodes, 144 cores, 800 GB mem

# %%
cores_per_nodes = 36
mem_per_node = 200
i = 4
ncpus = i*cores_per_nodes
ngpus = i
nodes = i
mem = i*mem_per_node
resourceCPU = 'select={nodes}:ncpus=36:mem=200gb'.format(nodes = nodes)
clusterCPU = PBSCluster(memory='{mem} GB'.format(mem = mem),
                        processes=ncpus,
                        cores=ncpus,
                        queue='casper',
                        walltime='02:00:00',
                        resource_spec=resourceCPU)
print(clusterCPU.job_script())
clusterCPU.scale(1)
client = Client(clusterCPU)
# Out:
# #!/usr/bin/env bash
#
# #PBS -N dask-worker
# #PBS -q casper
# #PBS -A NTDD0005
# #PBS -l select=4:ncpus=36:mem=200gb
# #PBS -l walltime=02:00:00
#
# /glade/work/hkashgar/conda-envs/geocat/bin/python -m distributed.cli.dask_worker tcp://10.12.205.43:42602 --nthreads 1 --nprocs 144 --memory-limit 5.17GiB --name dummy-name --nanny --death-timeout 60 --interface ib0 --protocol tcp://

# %%
client
# Out:
# <Client: 'tcp://10.12.205.43:42602' processes=0 threads=0, memory=0 B>

# %%
repsize = 10
repeat = np.zeros([repsize])
allData = pd.DataFrame()
for rep in range(repsize):
    numpy_res = geo.relhum(t_def, q_def, p_def,False).compute()
    time1 = time.time()
    numpy_res = geo.relhum(t_def, q_def, p_def,False).compute()
    time2 = time.time()
    repeat[rep] = time2-time1
    #numpy_results.append(numpy_res)
data = {'Routine': np.repeat(Routine, repsize),
        'Input':"Xarray with Dask array input",
        'Approach': np.repeat(np.__name__ , repsize),
        'ArraySize': np.repeat(ArraySize , repsize),
        'nodes': nodes,
        'iteration' : np.arange(1,repsize+1),
        'Runtime(s)': repeat}
allData = pd.concat([allData,pd.DataFrame(data)], ignore_index=True)
try:
    previous = pd.read_csv(csvpath)
    previous = pd.concat([previous,allData])
except FileNotFoundError:
    previous = allData
previous.to_csv(csvpath, index=False)

# %%
allData

# %%
clusterCPU.close()

# %% [markdown]
# # GPU

# %% [markdown]
# ## 1 GPU, 1 CPU, 200 GB mem

# %%
i = 1
ngpus = i
nodes = i
mem = i*mem_per_node
resouceGPU = 'select={nodes}:ncpus=1:ngpus=1:mem=200gb'.format(nodes = nodes)
clusterCUDA = PBSCluster(memory='{mem} GB'.format(mem = mem),
                         processes=1*i,
                         cores=1*i,
                         queue='casper',
                         walltime='02:00:00',
                         resource_spec=resouceGPU)
print(clusterCUDA.job_script())
clusterCUDA.scale(1)
client = Client(clusterCUDA)

# %%
client

# %%
allData = pd.DataFrame()
repsize = 10
repeat = np.zeros([repsize])
for rep in range(0,repsize):
    #create different sizes of arrays
    cupy_res = geo.relhum(t_def, q_def, p_def,True).compute()
    cp.cuda.runtime.deviceSynchronize()
    time1 = time.time()
    cupy_res = geo.relhum(t_def, q_def, p_def,True).compute()
    cp.cuda.runtime.deviceSynchronize()
    time2 = time.time()
    repeat[rep] = time2-time1
data = {'Routine': np.repeat(Routine, repsize),
        'Input':"Xarray with Dask array input",
        'Approach': np.repeat(cp.__name__ , repsize),
        'ArraySize': np.repeat(ArraySize , repsize),
        'nodes': nodes,
        'iteration' : np.arange(1,repsize+1),
        'Runtime(s)': repeat}
allData = pd.concat([allData,pd.DataFrame(data)], ignore_index=True)

# %%
allData

# %%
clusterCUDA.close()

# %% [markdown]
# ## 2 GPU, 2 CPU, 400 GB mem

# %%
i = 2
ncpus = i
ngpus = i
nodes = 1
mem = 300
resouceGPU = 'select={nodes}:ncpus={ncpus}:ngpus={ngpus}:mem={mem}gb'.format(nodes = nodes, ncpus = ncpus, ngpus = ngpus, mem = mem)
clusterCUDA = PBSCluster(memory='{mem} GB'.format(mem = mem),
                         processes=i,
                         cores=i,
                         queue='casper',
                         walltime='02:00:00',
                         resource_spec=resouceGPU)
print(clusterCUDA.job_script())
clusterCUDA.scale(1)
client = Client(clusterCUDA)

# %%
client

# %%
allData = pd.DataFrame()
repsize = 10
repeat = np.zeros([repsize])
for rep in range(0,repsize):
    #create different sizes of arrays
    cupy_res = geo.relhum(t_def, q_def, p_def,True).compute()
    cp.cuda.runtime.deviceSynchronize()
    time1 = time.time()
    cupy_res = geo.relhum(t_def, q_def, p_def,True).compute()
    cp.cuda.runtime.deviceSynchronize()
    time2 = time.time()
    repeat[rep] = time2-time1
data = {'Routine': np.repeat(Routine, repsize),
        'Input':"Xarray with Dask array input",
        'Approach': np.repeat(cp.__name__ , repsize),
        'ArraySize': np.repeat(ArraySize , repsize),
        'nodes': ngpus,
        'iteration' : np.arange(1,repsize+1),
        'Runtime(s)': repeat}
allData = pd.concat([allData,pd.DataFrame(data)], ignore_index=True)

# %%
allData

# %%
clusterCUDA.close()

# %% [markdown]
# ## 3 GPU, 3 CPU, 600 GB mem

# %%
i = 2
ncpus = i
ngpus = i
nodes = 1
mem = 300
resouceGPU = 'select={nodes}:ncpus={ncpus}:ngpus={ngpus}:mem={mem}gb'.format(nodes = nodes, ncpus = ncpus, ngpus = ngpus, mem = mem)
clusterCUDA = PBSCluster(memory='{mem} GB'.format(mem = mem),
                         processes=i,
                         cores=i,
                         queue='casper',
                         walltime='02:00:00',
                         resource_spec=resouceGPU)
print(clusterCUDA.job_script())
clusterCUDA.scale(1)
client = Client(clusterCUDA)

# %%
client

# %%
allData

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot(allData,name):
    nodes = np.unique(allData['nodes'])
    sd_numpy = np.zeros(len(nodes))
    sd_cupy = np.zeros(len(nodes))
    y_numpy = np.zeros(len(nodes))
    y_cupy = np.zeros(len(nodes))
    plt.rcParams.update({'font.size': 20})
    for i in range(0,len(nodes)):
        cupydata = allData.loc[(allData['nodes'] == nodes[i]) & (allData['Approach'] == 'cupy')]
        numpydata = allData.loc[(allData['nodes'] == nodes[i]) & (allData['Approach'] == 'numpy')]
        y_cupy[i] = np.mean(cupydata['Runtime(s)'])
        y_numpy[i] = np.mean(numpydata['Runtime(s)'])
        sd_cupy[i] = np.std(cupydata['Runtime(s)'])
        sd_numpy[i] = np.std(numpydata['Runtime(s)'])
    fig, ax = plt.subplots(figsize=(9, 6))
    ax.errorbar(nodes, y_numpy, yerr=sd_numpy, fmt='-o',label='numpy',markersize=20)
    ax.errorbar(nodes, y_cupy, yerr=sd_cupy, fmt='-D',label='cupy',markersize=20)
    ax.legend();  # Add a legend.
    ax.set_xlabel('nodes')  # Add an x-label to the axes.
    ax.set_ylabel('Runtime(s)')  # Add a y-label to the axes.
    ax.set_title(("Test_relhum"))
    #ax.set_xscale('log')
    #ax.set_yscale('log')
    #plt.savefig(name,dpi=fig.dpi)
def test_validation(res_numpy,res_cupy):
    assert np.allclose(res_numpy,res_cupy, atol=0.0000001)
