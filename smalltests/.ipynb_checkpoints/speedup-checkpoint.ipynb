# %%
import pandas as pd
met = pd.read_csv("Test_meteorology.csv")

# %%
df = met
df
# Out:
#               Routine  TestFunctionName Approach  ArraySize  iteration  \
# 0        Test_dewtemp   test_list_input    numpy         10          1
# 1        Test_dewtemp   test_list_input    numpy         10          2
# 2        Test_dewtemp   test_list_input    numpy         10          3
# 3        Test_dewtemp   test_list_input    numpy         10          4
# 4        Test_dewtemp   test_list_input    numpy         10          5
# ...               ...               ...      ...        ...        ...
# 1355  Test_relhum_ice  test_numpy_input     cupy   10000000          6
# 1356  Test_relhum_ice  test_numpy_input     cupy   10000000          7
# 1357  Test_relhum_ice  test_numpy_input     cupy   10000000          8
# 1358  Test_relhum_ice  test_numpy_input     cupy   10000000          9
# 1359  Test_relhum_ice  test_numpy_input     cupy   10000000         10
#
#       Runtime(s)
# 0       0.000194
# 1       0.000042
# 2       0.000039
# 3       0.000038
# 4       0.000046
# ...          ...
# 1355    0.010516
# 1356    0.010500
# 1357    0.010516
# 1358    0.010499
# 1359    0.010502
#
# [1360 rows x 6 columns]

# %%
Routines = np.unique(df['Routine'])
for rot in Routines:
    data = df.loc[(df['Routine'] == rot)]
    functions = np.unique(data['TestFunctionName'])
    max_speedup = 0
    for func in functions:
        subdata = data.loc[(data['TestFunctionName'] == func)]
        arraysizes = np.unique(subdata['ArraySize'])
        sd_numpy = np.zeros(len(arraysizes))
        sd_cupy = np.zeros(len(arraysizes))
        y_numpy = np.zeros(len(arraysizes))
        y_cupy = np.zeros(len(arraysizes))
        for i in range(0,len(arraysizes)):
            cupydata = subdata.loc[(subdata['ArraySize'] == arraysizes[i]) & (subdata['Approach'] == 'cupy')]
            numpydata = subdata.loc[(subdata['ArraySize'] == arraysizes[i]) & (subdata['Approach'] == 'numpy')]
            y_cupy[i] = np.mean(cupydata['Runtime(s)'])
            y_numpy[i] = np.mean(numpydata['Runtime(s)'])
            sd_cupy[i] = np.std(cupydata['Runtime(s)'])
            sd_numpy[i] = np.std(numpydata['Runtime(s)'])
        max_speedup = np.max(y_numpy/y_cupy)
        print(rot,func)
        print(max_speedup)

# %%
data = df.loc[(df['Routine'] == "Test_heat_index")]

# %%
data = data.loc[(data['TestFunctionName'] == "test_numpy_input")]

# %%
data
# Out:
#              Routine  TestFunctionName Approach  ArraySize  iteration  \
# 420  Test_heat_index  test_numpy_input    numpy         10          1
# 421  Test_heat_index  test_numpy_input    numpy         10          2
# 422  Test_heat_index  test_numpy_input    numpy         10          3
# 423  Test_heat_index  test_numpy_input    numpy         10          4
# 424  Test_heat_index  test_numpy_input    numpy         10          5
# ..               ...               ...      ...        ...        ...
# 515  Test_heat_index  test_numpy_input     cupy     100000          6
# 516  Test_heat_index  test_numpy_input     cupy     100000          7
# 517  Test_heat_index  test_numpy_input     cupy     100000          8
# 518  Test_heat_index  test_numpy_input     cupy     100000          9
# 519  Test_heat_index  test_numpy_input     cupy     100000         10
#
#      Runtime(s)
# 420    0.000469
# 421    0.000231
# 422    0.000229
# 423    0.000218
# 424    0.000223
# ..          ...
# 515    3.080249
# 516    3.118427
# 517    3.059439
# 518    3.253667
# 519    3.229244
#
# [100 rows x 6 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np
arraysizes = np.unique(data['ArraySize'])
sd_numpy = np.zeros(len(arraysizes))
sd_cupy = np.zeros(len(arraysizes))
y_numpy = np.zeros(len(arraysizes))
y_cupy = np.zeros(len(arraysizes))

for i in range(0,len(arraysizes)):
    cupydata = data.loc[(data['ArraySize'] == arraysizes[i]) & (data['Approach'] == 'cupy')]
    numpydata = data.loc[(data['ArraySize'] == arraysizes[i]) & (data['Approach'] == 'numpy')]
    y_cupy[i] = np.mean(cupydata['Runtime(s)'])
    y_numpy[i] = np.mean(numpydata['Runtime(s)'])
    sd_cupy[i] = np.std(cupydata['Runtime(s)'])
    sd_numpy[i] = np.std(numpydata['Runtime(s)'])

# %%
fig, ax = plt.subplots(figsize=(9, 6))
ax.errorbar(arraysizes, y_numpy, yerr=sd_numpy, fmt='-o')
ax.errorbar(arraysizes, y_cupy, yerr=sd_cupy, fmt='-o')
ax.plot(arraysizes, y_numpy, label='numpy',color="steelblue")
ax.plot(arraysizes, y_cupy, label='cupy',color="darkorange")  # Plot more data on the axes...
ax.legend();  # Add a legend.
ax.set_xlabel('ArraySize')  # Add an x-label to the axes.
ax.set_ylabel('Runtime(s)')  # Add a y-label to the axes.
ax.set_title(("Test_relhum", "test_numpy_input"))
ax.set_xscale('log')
ax.set_yscale('log')
plt.savefig("Test_heat_index.jpg",dpi=fig.dpi)
